# %%
import os
from bs4 import BeautifulSoup as bs
import requests
import selenium.webdriver as webdriver
import selenium.webdriver.support.ui as ui
from selenium.webdriver.common.keys import Keys
from splinter import Browser
import time
import pandas as pd

# %%
x = 0 #counter

#Beautiful Soup finds all Job Title links on the agency page and the loop begins
for link in soup_level1.find_all('a', id=re.compile("^MainContent_uxLevel2_JobTitles_uxJobTitleBtn_")):
    
    #Selenium visits each Job Title page
    python_button = driver.find_element_by_id('MainContent_uxLevel2_JobTitles_uxJobTitleBtn_' + str(x))
    python_button.click() #click link
    
    #Selenium hands of the source of the specific job page to Beautiful Soup
    soup_level2=BeautifulSoup(driver.page_source, 'lxml')

    #Beautiful Soup grabs the HTML table on the page
    table = soup_level2.find_all('table')[0]
    
    #Giving the HTML table to pandas to put in a dataframe object
    df = pd.read_html(str(table),header=0)
    
    #Store the dataframe in a list
    datalist.append(df[0])
    
    #Ask Selenium to click the back button
    driver.execute_script("window.history.go(-1)") 
    
    #increment the counter variable before starting the loop over
    x += 1
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Access to this page has been denied.
#   </title>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300" rel="stylesheet"/>
#   <style>
# ...

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
time.sleep(5)

url2 = 'https://www.wine-searcher.com/find/cab+sauv+valley+county+north+coast+california+usa/1/usa-ca-y/-/x'
browser.visit(url2)
time.sleep(5)
for x in (1,2):
        html = browser.html
        soup = bs(html, 'html.parser')
        table = soup.find_all('table')[0]
        df = pd.read_html(str(table),header=0)
        datalist.append(df[0])
        try:
            print(Divs)
        
        except AttributeError as e:
            print(e)

time.sleep(5)
# Out:
# None
# None

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
time.sleep(5)

url2 = 'https://www.wine-searcher.com/find/cab+sauv+valley+county+north+coast+california+usa/1/usa-ca-y/-/x'
browser.visit(url2)
time.sleep(20)
# Out:
# <html lang="en-US"><head>
# <title>Cab Sauv Valley County North Coast California Usa search results in CA, USA</title>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <script src="https://cdn.ampproject.org/rtv/012005012256000/amp4ads-host-v0.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-M0W3BEYMXL&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5FD5S84"></script><script>window._pxAppId = 'PXK6S8okp3';
# window._pxParam1 = 'HZZ4CVQ3FH10027';
# window._pxParam2 = '';</script>
# <meta property="og:title" content="Cab Sauv Valley County North Coast California Usa search results in CA, USA">
# ...

# %%
datalist=[]
snl=[]
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
time.sleep(5)
x = 0
url2 = 'https://www.wine-searcher.com/find/cab+sauv+valley+county+north+coast+california+usa/1/usa-ca-y/-/x'
browser.visit(url2)
time.sleep(5)
for c in range(20):
        html = browser.html
        soup = bs(html, 'html.parser')
        datalist.append([html])
        print()
        try:
            browser.click_link_by_partial_text('>')
            time.sleep(5)
        except:
            print("Scraping Complete")
# Out:
# Scraping Complete
#
# Scraping Complete
#
# Scraping Complete
#
# Scraping Complete
#
# Scraping Complete
#
# Scraping Complete
#
# Scraping Complete
#
# Scraping Complete

# %%
datalist
# Out:
# [['<html lang="en-US"><head>\n<title>Cab Sauv Valley County North Coast California Usa search results in CA, USA</title>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">    \n<script src="https://cdn.ampproject.org/rtv/012005012256000/amp4ads-host-v0.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-M0W3BEYMXL&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5FD5S84"></script><script>window._pxAppId = \'PXK6S8okp3\';\nwindow._pxParam1 = \'JVC4CZS3FZD0054\';\nwindow._pxParam2 = \'\';</script>\n<meta property="og:title" content="Cab Sauv Valley County North Coast California Usa search results in CA, USA">\n<meta name="description" con
# ...

# %%
therteen_twenty=[]

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
time.sleep(5)
x = 0
url2 = 'https://www.wine-searcher.com/find/cab+sauv+valley+county+north+coast+california+usa/1/usa-ca-y/-/x/301'
browser.visit(url2)
time.sleep(5)
for c in range(8):
        html = browser.html
        soup = bs(html, 'html.parser')
        therteen_twenty.append([html])
        try:
            browser.click_link_by_partial_text('>')
            time.sleep(5)
        except:
            print("Scraping Complete")
# Out:
# Scraping Complete

# %%
len(therteen_twenty)
# Out:
# 8

# %%
therteen_twenty[0]
# Out:
# ['<html lang="en-US"><head>\n<title>Cab Sauv Valley County North Coast California Usa search results in CA, USA Page 13. </title>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">    \n<script src="https://cdn.ampproject.org/rtv/012005012256000/amp4ads-host-v0.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-M0W3BEYMXL&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5FD5S84"></script><script>window._pxAppId = \'PXK6S8okp3\';\nwindow._pxParam1 = \'VMW4C05JF4600D5\';\nwindow._pxParam2 = \'\';</script>\n<meta property="og:title" content="Cab Sauv Valley County North Coast California Usa search results in CA, USA Page 13. ">\n<meta nam
# ...

# %%
    a = therteen_twenty[0]
    b = therteen_twenty[2]
    c = therteen_twenty[3]
    d = therteen_twenty[4]
    e = therteen_twenty[5]
    f = therteen_twenty[6]
    g = therteen_twenty[7]            
    h = therteen_twenty[1]
for c in a:
        a1 = pd.read_html(c)
for c in b:
        b1 = pd.read_html(c)
for g in therteen_twenty[3]:
        c1 = pd.read_html(g)
for c in d:
        d1 = pd.read_html(c)
for c in e:
        e1 = pd.read_html(c)
for c in f:
        f1 = pd.read_html(c)
for c in therteen_twenty[7]:
        g1 = pd.read_html(c)
for c in h:
        h1 = pd.read_html(c)

# %%
rr=[a1,h1,b1,c1,d1,e1,f1,g1]

# %%
 def myfunction(x):
         return g==x[1] 
         return g.columns==['wine', 'region', 'price','Popularity'];
 

for j in range,8:
# Out:
# <class 'range'>
# 8

# %%
a1=a1[1]
a1.columns =['wine', 'region', 'price','Popularity']
a1
# Out:
#                                                  wine  \
# 0                                           Wine Name
# 1   Gargiulo Vineyards '575 OVX G Major 7 Study' C...
# 2   Levy & McClellan Cabernet Sauvignon, Napa Vall...
# 3   Seven Stones Cabernet Sauvignon, Napa Valley, USA
# 4   Jarvis Estate Cave Fermented Cabernet Sauvigno...
# 5   Salvestrin Winery 'Salvestrin Estate Vineyard'...
# 6   Rutherford Hill Cabernet Sauvignon, Napa Valle...
# 7   Stag's Leap Wine Cellars Cabernet Sauvignon, N...
# 8   Lewelling Vineyards Wight Vineyard Cabernet Sa...
# 9   Tor Wines Beckstoffer To Kalon Vineyard Cabern...
# 10  Salvestrin Winery 'Three D' Cabernet Sauvignon...
# 11  Pahlmeyer Jayson Cabernet Sauvignon, Napa Vall...
# 12  Maybach Family Vineyards Amoenus Vineyard Cabe...
# 13  Windsor Vineyards Cabernet Sauvignon, Napa Val...
# 14  Robert Craig Winery Howell Mountain Cabernet S...
# 15  Gamble Family Vineyards Cabernet Sauvignon, Na...
# ...

# %%
h1=h1[1]
h1.columns =['wine', 'region', 'price','Popularity']
b1=b1[1]
b1.columns =['wine', 'region', 'price','Popularity']
c1=c1[1]
h1.columns =['wine', 'region', 'price','Popularity']
d1=d1[1]
h1.columns =['wine', 'region', 'price','Popularity']
e1=e1[1]
e1.columns =['wine', 'region', 'price','Popularity']
f1=f1[1]
f1.columns =['wine', 'region', 'price','Popularity']

# %%
df_all_cols = pd.concat([a1, b1], axis = 0)
df_all_cols
# Out:
#                                                  wine  \
# 0                                           Wine Name
# 1   Gargiulo Vineyards '575 OVX G Major 7 Study' C...
# 2   Levy & McClellan Cabernet Sauvignon, Napa Vall...
# 3   Seven Stones Cabernet Sauvignon, Napa Valley, USA
# 4   Jarvis Estate Cave Fermented Cabernet Sauvigno...
# 5   Salvestrin Winery 'Salvestrin Estate Vineyard'...
# 6   Rutherford Hill Cabernet Sauvignon, Napa Valle...
# 7   Stag's Leap Wine Cellars Cabernet Sauvignon, N...
# 8   Lewelling Vineyards Wight Vineyard Cabernet Sa...
# 9   Tor Wines Beckstoffer To Kalon Vineyard Cabern...
# 10  Salvestrin Winery 'Three D' Cabernet Sauvignon...
# 11  Pahlmeyer Jayson Cabernet Sauvignon, Napa Vall...
# 12  Maybach Family Vineyards Amoenus Vineyard Cabe...
# 13  Windsor Vineyards Cabernet Sauvignon, Napa Val...
# 14  Robert Craig Winery Howell Mountain Cabernet S...
# 15  Gamble Family Vineyards Cabernet Sauvignon, Na...
# ...

# %%
lf=pd.read_csv()
